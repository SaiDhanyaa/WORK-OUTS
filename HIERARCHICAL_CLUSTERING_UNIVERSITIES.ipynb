# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiDhanyaa/WORK-OUTS/blob/main/HIERARCHICAL_CLUSTERING_UNIVERSITIES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPRT HIERARCHICAL CLUSTERING LIBRARIES
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sn

# %%
univ=pd.read_csv("/content/Universities.csv")

# %%
# Normalization function 
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
# Normalized data frame (considering the numerical part of data)
df_norm = norm_func(univ.iloc[:,1:])

# %% [markdown]
# ## **SINGLE LINKAGE METHOD**

# %%
# create dendrogram
dendrogram1 = sch.dendrogram(sch.linkage(df_norm, method='single'))

# %%
# create clusters
hc1 = AgglomerativeClustering(n_clusters=3, affinity = 'euclidean', linkage = 'single')

# %%
# save clusters for chart
y_hc1 = hc1.fit_predict(df_norm)
Clusters1=pd.DataFrame(y_hc1,columns=['Clusters'])

# %%
Clusters1

# %%
univ['h_clusterid'] = Clusters1

# %%
univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  h_clusterid
# 0          Brown  1310     89      22       13     22704        94            0
# 1        CalTech  1415    100      25        6     63575        81            0
# 2            CMU  1260     62      59        9     25026        72            1
# 3       Columbia  1310     76      24       12     31510        88            0
# 4        Cornell  1280     83      33       13     21864        90            0
# 5      Dartmouth  1340     89      23       10     32162        95            0
# 6           Duke  1315     90      30       12     31585        95            0
# 7     Georgetown  1255     74      24       12     20126        92            0
# 8        Harvard  1400     91      14       11     39525        97            0
# 9   JohnsHopkins  1305     75      44        7     58691        87            0
# 10           MIT  1380     94      30       10     34870        91            0
# 11  Northwestern  1260     85      39       11     28052        89            0
# 12     NotreDame  1255     81      42       13     15122        94            0
# 13     PennState  1081     38      54       18     10185        80            0
# 14     Princeton  1375     91      14        8     30220        95            0
# 15        Purdue  1005     28      90       19      9066        69            0
# 16      Stanford  1360     90      20       12     36450        93            0
# 17      TexasA&M  1075     49      67       25      8704        67            2
# 18    UCBerkeley  1240     95      40       17     15140        78            0
# 19      UChicago  1290     75      50       13     38380        87            0
# 20     UMichigan  1180     65      68       16     15470        85            0
# 21         UPenn  1285     80      36       11     27553        90            0
# 22           UVA  1225     77      44       14     13349        92            0
# 23    UWisconsin  1085     40      69       15     11857        71            0
# 24          Yale  1375     95      19       11     43514        96            0

# %% [markdown]
# ## **COMPLETE LINKAGE METHOD**

# %%
# create dendrogram
dendrogram2 = sch.dendrogram(sch.linkage(df_norm, method='complete'))

# %%
# create clusters
hc2 = AgglomerativeClustering(n_clusters=3, affinity = 'euclidean', linkage = 'complete')

# %%
# save clusters for chart
y_hc2 = hc2.fit_predict(df_norm)
Clusters2=pd.DataFrame(y_hc2,columns=['Clusters'])

# %%
Clusters2

# %%
univ['h_clusterid'] = Clusters2

# %%
univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  h_clusterid
# 0          Brown  1310     89      22       13     22704        94            1
# 1        CalTech  1415    100      25        6     63575        81            1
# 2            CMU  1260     62      59        9     25026        72            0
# 3       Columbia  1310     76      24       12     31510        88            1
# 4        Cornell  1280     83      33       13     21864        90            1
# 5      Dartmouth  1340     89      23       10     32162        95            1
# 6           Duke  1315     90      30       12     31585        95            1
# 7     Georgetown  1255     74      24       12     20126        92            1
# 8        Harvard  1400     91      14       11     39525        97            1
# 9   JohnsHopkins  1305     75      44        7     58691        87            1
# 10           MIT  1380     94      30       10     34870        91            1
# 11  Northwestern  1260     85      39       11     28052        89            1
# 12     NotreDame  1255     81      42       13     15122        94            1
# 13     PennState  1081     38      54       18     10185        80            2
# 14     Princeton  1375     91      14        8     30220        95            1
# 15        Purdue  1005     28      90       19      9066        69            2
# 16      Stanford  1360     90      20       12     36450        93            1
# 17      TexasA&M  1075     49      67       25      8704        67            0
# 18    UCBerkeley  1240     95      40       17     15140        78            1
# 19      UChicago  1290     75      50       13     38380        87            1
# 20     UMichigan  1180     65      68       16     15470        85            1
# 21         UPenn  1285     80      36       11     27553        90            1
# 22           UVA  1225     77      44       14     13349        92            1
# 23    UWisconsin  1085     40      69       15     11857        71            2
# 24          Yale  1375     95      19       11     43514        96            1

# %% [markdown]
# ### **AVERAGE LINKAGE METHOD**

# %%
# create dendrogram
dendrogram3 = sch.dendrogram(sch.linkage(df_norm, method='average'))

# %%
# create clusters
hc3 = AgglomerativeClustering(n_clusters=3, affinity = 'euclidean', linkage = 'average')

# %%
# save clusters for chart
y_hc3 = hc3.fit_predict(df_norm)
Clusters3=pd.DataFrame(y_hc3,columns=['Clusters'])

# %%
Clusters3

# %%
univ['h_clusterid'] = Clusters3

# %%
univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  h_clusterid
# 0          Brown  1310     89      22       13     22704        94            2
# 1        CalTech  1415    100      25        6     63575        81            2
# 2            CMU  1260     62      59        9     25026        72            0
# 3       Columbia  1310     76      24       12     31510        88            2
# 4        Cornell  1280     83      33       13     21864        90            2
# 5      Dartmouth  1340     89      23       10     32162        95            2
# 6           Duke  1315     90      30       12     31585        95            2
# 7     Georgetown  1255     74      24       12     20126        92            2
# 8        Harvard  1400     91      14       11     39525        97            2
# 9   JohnsHopkins  1305     75      44        7     58691        87            2
# 10           MIT  1380     94      30       10     34870        91            2
# 11  Northwestern  1260     85      39       11     28052        89            2
# 12     NotreDame  1255     81      42       13     15122        94            2
# 13     PennState  1081     38      54       18     10185        80            1
# 14     Princeton  1375     91      14        8     30220        95            2
# 15        Purdue  1005     28      90       19      9066        69            1
# 16      Stanford  1360     90      20       12     36450        93            2
# 17      TexasA&M  1075     49      67       25      8704        67            0
# 18    UCBerkeley  1240     95      40       17     15140        78            2
# 19      UChicago  1290     75      50       13     38380        87            2
# 20     UMichigan  1180     65      68       16     15470        85            2
# 21         UPenn  1285     80      36       11     27553        90            2
# 22           UVA  1225     77      44       14     13349        92            2
# 23    UWisconsin  1085     40      69       15     11857        71            1
# 24          Yale  1375     95      19       11     43514        96            2

# %% [markdown]
# ## **CENTROID LINKAGE METHOD**

# %%
# create dendrogram
dendrogram4 = sch.dendrogram(sch.linkage(df_norm, method='centroid'))

# %%
# create clusters
hc4 = AgglomerativeClustering(n_clusters=3, affinity = 'euclidean', linkage = 'ward')

# %%
# save clusters for chart
y_hc4 = hc4.fit_predict(df_norm)
Clusters4 = pd.DataFrame(y_hc4,columns=['Clusters'])

# %%
Clusters4

# %%
univ['h_clusterid'] = Clusters4

# %%
univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  h_clusterid
# 0          Brown  1310     89      22       13     22704        94            0
# 1        CalTech  1415    100      25        6     63575        81            0
# 2            CMU  1260     62      59        9     25026        72            1
# 3       Columbia  1310     76      24       12     31510        88            0
# 4        Cornell  1280     83      33       13     21864        90            0
# 5      Dartmouth  1340     89      23       10     32162        95            0
# 6           Duke  1315     90      30       12     31585        95            0
# 7     Georgetown  1255     74      24       12     20126        92            0
# 8        Harvard  1400     91      14       11     39525        97            0
# 9   JohnsHopkins  1305     75      44        7     58691        87            0
# 10           MIT  1380     94      30       10     34870        91            0
# 11  Northwestern  1260     85      39       11     28052        89            0
# 12     NotreDame  1255     81      42       13     15122        94            0
# 13     PennState  1081     38      54       18     10185        80            2
# 14     Princeton  1375     91      14        8     30220        95            0
# 15        Purdue  1005     28      90       19      9066        69            2
# 16      Stanford  1360     90      20       12     36450        93            0
# 17      TexasA&M  1075     49      67       25      8704        67            1
# 18    UCBerkeley  1240     95      40       17     15140        78            0
# 19      UChicago  1290     75      50       13     38380        87            0
# 20     UMichigan  1180     65      68       16     15470        85            0
# 21         UPenn  1285     80      36       11     27553        90            0
# 22           UVA  1225     77      44       14     13349        92            0
# 23    UWisconsin  1085     40      69       15     11857        71            2
# 24          Yale  1375     95      19       11     43514        96            0

# %% [markdown]
# ## ***THUS, WE HAVE CREATED 3 CLUSTERS 0,1,2. AND THE UNIVERSITIES ARE APPENDED TO RESPECTIVE CLUSTERS BASED ON THE SIMILARITIESS THEY POSSESS***
